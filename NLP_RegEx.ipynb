# %% [markdown]
# <a href="https://colab.research.google.com/github/kskrao219/NLP/blob/main/NLP_RegEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***RegEx in Python***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

# %%
#Match returns the first appearance of the element in the structured dataset
string = "Tiger is the national animal of india "
pattern = "Tiger"
result=re.match(pattern,string).group(0)
print(result)
# Out:
# Tiger

# %%
#Search seaches the element in structured dataset
string2="national animal of india is tiger "
pattern="tiger"
res2=re.search(pattern,string2).group(0)
print(res2)
# Out:
# tiger

# %%
#Finadll finds all the occurences in the pattern 
string3 = "national animal is tiger and national fruit is mango"
pattern="national"
res3=re.findall(pattern,string3)
print(res3)
# Out:
# ['national', 'national']

# %%
#res3 is a list ,Findeiter returns the indexes of the string ,res3 is the iterator now
res3=re.finditer(pattern,string3)
for i in res3:
  print(i.start())
# Out:
# 0
# 29

# %%
#Expression to match date like strings in the structured data set 
#\d is used for digits ,{2} defines no of digits
string4="john 34-3456 12-05-2017 XYZ 56-7821 11-11-2020,ABC 23-897 12-07-2016"
date_pattern = r'\d{2}-\d{2}-\d{4}' 
res4=re.findall(date_pattern,string4)
print(res4)
# Out:
# ['12-05-2017', '11-11-2020', '12-07-2016']

# %%
#split() is used to split string by delimiters
string5="he research, which took, place in America, suggested that age was a significant ,factor.he research, which took place in ,America, suggested that age was a significant fact"
split_pattern=r'[,,\s]'
re.split(split_pattern,string5)
# Out:
# ['he',
#  'research',
#  '',
#  'which',
#  'took',
#  '',
#  'place',
#  'in',
#  'America',
#  '',
#  'suggested',
#  'that',
#  'age',
#  'was',
#  'a',
#  'significant',
#  '',
#  'factor.he',
#  'research',
#  '',
#  'which',
#  'took',
#  'place',
#  'in',
#  '',
#  'America',
#  '',
#  'suggested',
#  'that',
#  'age',
#  'was',
#  'a',
#  'significant',
#  'fact']

# %%
#sub is used to find and replace 
string6="cricket is the most popular game in india"
pattern="india"
replacement = "the world"
re.sub(pattern,replacement,string6)
# Out:
# 'cricket is the most popular game in the world'

# %% [markdown]
# # **END**
