# %% [markdown]
# <a href="https://colab.research.google.com/github/kskrao219/NLP/blob/main/Title-Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#handling url
import urllib 
#handling or parsing HTML files
from bs4 import BeautifulSoup 
#natural language tool kit
import nltk

# %%
#to remove the stopword like or, the , and etc
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
#getting info from the website
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/NASA')
html = response.read()

# %%
#HTML decoding
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text(strip = True)
print(text)
# Out:
# NASA - Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"afac96b4-bf71-48d5-9248-7502c95def67","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"NASA","wgTitle":"NASA","wgCurRevisionId":1029104701,"wgRevisionId":1029104701,"wgArticleId":18426568,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with non-numeric formatnum arguments","Webarchive template wayback links","Webarchive template webcite links","CS1 Dutch-language sources (nl)","CS1 errors: missing periodical","Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely move-protected pages"
# ...

# %%
tokens = [t for t in text.split()]
sr = stopwords.words('english')
clean_tokens = tokens[:]
print(tokens)
# Out:
# ['NASA', '-', 'Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"afac96b4-bf71-48d5-9248-7502c95def67","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"NASA","wgTitle":"NASA","wgCurRevisionId":1029104701,"wgRevisionId":1029104701,"wgArticleId":18426568,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages', 'with', 'non-numeric', 'formatnum', 'arguments","Webarchive', 'template', 'wayback', 'links","Webarchive', 'template', 'webcite', 'links","CS1', 'Dutch-language', 'sources', '(nl)","CS1', 'errors:', 'missing', 'periodical","Articles', 'with', 'short', 'description","Short', 'description', 'is
# ...

# %%
#Removing stop words
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)

# %%
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key)+':'+str(val))
# Out:
# Streaming output truncated to the last 5000 lines.
# provided:2
# useful:1
# experience:1
# US–Russian:1
# Shuttle–Mirprogram[58]and:1
# International:16
# Station.LeadershipMain:1
# article:List:1
# Administrators:2
# Deputy:2
# NASAAdministratorBill:1
# NelsonThe:1
# agency's:3
# leader,NASA's:1
# administrator,:1
# nominated:1
# thePresident:1
# Statessubject:1
# approval:1
# Senate,[59]and:1
# reports:2
# serves:1
# senior:1
# advisor.:1
# Though:1
# exploration:9
# ostensibly:1
# non-partisan,:1
# appointee:1
# usually:2
# President's:1
# political:3
# party:2
# (DemocraticorRepublican),:1
# administrator:10
# chosen:3
# Presidency:1
# changes:1
# parties.:1
# exceptions:1
# been:DemocratThomas:1
# O.:1
# Paine,:1
# acting:2
# DemocratLyndon:1
# B.:6
# Johnson,:1
# RepublicanRichard:1
# Nixontried:1
# failed:1
# get:4
# choices:1
# accept:1
# job.:1
# Paine:1
# confirmed:3
# Senate:4
# 1969:1
# served:3
# September:29
# 1970.[60]RepublicanJames:1
# C.:12
# Fletcher,:2
# ...

# %%
freq.plot(20, cumulative=False)
